# %% [markdown]
# <a href="https://colab.research.google.com/github/igorjoz/ai-course-gp/blob/main/lesson_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kod wypisuje słowo Hello**
#
# > cytat

# %%
num=3
print("Hello")
# Out:
# Hello

# %%
print("123")
print(num)
# Out:
# 123
# 3

# %%
num = 10
float_num = 5.50
text = "Hello"
bool_variable = False

print(text)

print(f"liczba: {num}, średnia: {float_num}")
print(type(num))
# Out:
# Hello
# liczba: 10, średnia: 5.5
# <class 'int'>

# %%
games = ["Prison Architect", "Rimworld", "Life is Strange"]
print(games)
print(games[0])

games.append("CS")
print(games)
# Out:
# ['Prison Architect', 'Rimworld', 'Life is Strange']
# Prison Architect
# ['Prison Architect', 'Rimworld', 'Life is Strange', 'CS']

# %%
print(int("011110", 2))
print(int("FF", 16))
# Out:
# 30
# 255

# %%
temperature = float(input("Podaj temperaturę: "))

if temperature < 20:
  print("Podwyższam temperaturę")
elif temperature > 22:
  print("Wyłączam się")
else:
  print("Temperatura w normie")
# Out:
# Podaj temperaturę: 15
# Podwyższam temperaturę

# %%
for game in games:
  print(game)


for i in range(5):
  print(i)

for i in range(-8, 19, 3):
  print(i)

def add(a, b):
  print(a+b)

add(9, 19)
# Out:
# Prison Architect
# Rimworld
# Life is Strange
# CS
# 0
# 1
# 2
# 3
# 4
# -8
# -5
# -2
# 1
# 4
# 7
# 10
# 13
# 16
# 28
